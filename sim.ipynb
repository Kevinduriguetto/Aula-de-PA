# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevinduriguetto/Aula-de-PA/blob/main/sim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura de decisões (if, elif e else)

# Escrever um programa que compara 02 números

# Entradas
a = int (input("Digite um número inteiro: "))
b = int (input("Digite um número inteiro: "))

#processamento / saída

if a == b:
 print (f"{a} é igual {b}")

else:
  print (f"{a} é diferente de {b}")
# Out:
# Digite um número inteiro: 2
# Digite um número inteiro: 121
# 2 é diferente de 121

# %%
# Escrever um programa que verifica se o número digitidado é par ou impar

# entrada

numero = int (input("digite um numero"))


# processamento / Saída

if numero % 2 == 0:

    print (f" o numero {numero} é par")

else:
    print (f"o numero {numero} e impar")
# Out:
# digite um numero23
# o numero 23 e impar

# %%
# Escrever um programa que o usuario digita o nome e a idade e verifica se o usario e criança

# Entrada

nome = str(input("digite seu nome "))
idade = int(input("digite sua idade "))

# Processamento / saida

if idade < 12 :
  print ("crianca")
elif idade < 18 :
  print("adolecente")
else:
  print ("adulto")
# Out:
# digite seu nome skibidi
# digite sua idade 3
# crianca

# %%
# Entrada

print("----------Calculadora----------")
print("                               ")
print("-------------Menu--------------")
print("                               ")
print("opção = 1 - soma")
print("opção = 2 - subtração")
print("opção = 3 - Multiplicação")
print("opção = 4 - Divisão")
print("-------------------------------")

# Entrada

numero = float (input("digite um número"))
opcao = int (input("escolha a opção desejada: "))
numero1 = float(input("digite seu numero"))

# Processamento / saida

if opcao == 1:
  print (f"a soma de {numero} e {numero1} e igual a {numero + numero1}")
elif opcao == 2:
  print (f"a subtração de {numero} e {numero1} é igual a {numero - numero1}")
elif opcao == 3:
  print (f"a multiplicação de {numero} e {numero1} é igual a {numero * numero1}")
elif opcao == 2:

  if numero1 != 0:
    print (f"a divisão de {numero} e {numero1} é igual a {numero / numero1}")
  else:
    print ("Erro: Não é possível dividir por zero")
else:
    print ("opção invalida")
# Out:
# ----------Calculadora----------
#
# -------------Menu--------------
#
# opção = 1 - soma
# opção = 2 - subtração
# opção = 3 - Multiplicação
# opção = 4 - Divisão
# -------------------------------
# digite um número32
# escolha a opção desejada: 2
# digite seu numero32
# a subtração de 32.0 e 32.0 é igual a 0.0
